# %% [markdown]
# <a href="https://colab.research.google.com/github/Sandr001/myProjects/blob/development/Sales-Data-Assignment-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# MGT7216 Assignment-1 Sales Data
print("MGT7216 Assignment-1 Sales Data")
# Out:
# MGT7216 Assignment-1 Sales Data
